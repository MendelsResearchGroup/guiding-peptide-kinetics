# %% [markdown]
# ### Visualise protein trajectory

# %%
import mdtraj as md
import nglview as nv

traj = md.load('../data/YYDPETGTWE/output/run_000/run_000_center.xtc', top='../data/YYDPETGTWE/output/YYDPETGTWE_newbox.gro')
print(traj)
view = nv.show_mdtraj(traj) 
# view.clear_representations()
view.add_representation("cartoon")
#view.add_representation("ball+stick", selection="resname NA or resname CL or resname SOL")
view
# Out:
# <mdtraj.Trajectory with 4 frames, 160 atoms, 10 residues, and unitcells>
# NGLWidget(max_frame=3)
